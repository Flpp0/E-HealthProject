# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/Users/filippo/ScrivaniaLocale/E-HealthProject/dataset.csv",index_col=0)
print(df.head(10))
# Out:
#     age  gender  education  marital  income  phq_1  phq_2  phq_3  phq_4  \
# 0  42.0       1        5.0        1   18000      0    0.0    1.0      0
# 1  51.0       3       18.0        1   23000      0    0.0    0.0      0
# 2  40.0       0        8.0        1   10000      0    0.0    0.0      0
# 3  19.0       0       25.0        5   31000      2    1.0    0.0      0
# 4  42.0       2       13.0        1   40000      0    1.0    0.0      0
# 5  48.0       2       13.0        1   11000      0    0.0    0.0      1
# 6  33.0       0       22.0        2   36400      0    1.0    0.0      2
# 7  55.0       2        8.0        2   28000      0    0.0    0.0      0
# 8  40.0       3       18.0        3   12000      0    0.0    0.0      1
# 9  46.0       2       13.0        1   35000      2    0.0    2.0      1
#
#    phq_5  ...  ccs_3  ccs_4  ccs_5  ccs_6  ccs_7  ccs_8  ccs_9  ccs_10  \
# 0      0  ...    5.0    1.0    4.0    3.0      0      4      0       0
# 1      0  ...    3.0    6.0    6.0    1.0      0      1      4       0
# 2      1  ...    6.0    6.0    6.0    0.0      5      0      2       1
# 3      2  ...    6.0    4.0    0.0    4.0      6      0      1       1
# 4      1  ...    6.0    6.0    0.0    0.0      6      1      1       0
# 5      0  ...    0.0    1.0    0.0    0.0      5      4      3       1
# 6      1  ...    6.0    3.0    0.0    6.0      5      0      2       2
# 7      0  ...    3.0    6.0    6.0    4.0      0      0      6       1
# 8      0  ...    5.0    0.0    3.0    2.0      0      3      1       2
# 9      0  ...    6.0    0.0    1.0    6.0      6      1      6       6
#
#    ccs_11  ccs_12
# 0       3       1
# 1       3       6
# 2       6       3
# 3       0       4
# 4       5       4
# 5       5       0
# 6       1       6
# 7       0       6
# 8       6       0
# 9       0       5
#
# [10 rows x 54 columns]

# %%
#Dimensions
print('Dimensions: ', df.shape) #160x29
#Statistics
print(df.info)
# Out:
# Dimensions:  (150, 54)
# <bound method DataFrame.info of       age  gender  education  marital  income  phq_1  phq_2  phq_3  phq_4  \
# 0    42.0       1        5.0        1   18000      0    0.0    1.0      0
# 1    51.0       3       18.0        1   23000      0    0.0    0.0      0
# 2    40.0       0        8.0        1   10000      0    0.0    0.0      0
# 3    19.0       0       25.0        5   31000      2    1.0    0.0      0
# 4    42.0       2       13.0        1   40000      0    1.0    0.0      0
# ..    ...     ...        ...      ...     ...    ...    ...    ...    ...
# 155  29.0       2       18.0        0   25000      0    2.0    0.0      2
# 156  40.0       1       13.0        5   27000      2    1.0    2.0      0
# 157  40.0       0       13.0        0   26000      0    0.0    2.0      1
# 158  41.0       1        8.0        1   11000      0    0.0    1.0      0
# 159  55.0       0        8.0        2   32199      0    0.0    0.0      0
#
#      phq_5  ...  ccs_3  ccs_4  ccs_5  ccs_6  ccs_7  ccs_8  ccs_9  ccs_10  \
# 0        0  ...    5.0    1.0    4.0    3.0      0      4      0       0
# 1        0  ...    3.0    6.0    6.0    1.0      0      1      4       0
# 2        1  ...    6.0    6.0    6.0    0.0      5      0      2       1
# 3        2  ...    6.0    4.0    0.0    4.0      6      0      1       1
# 4        1  ...    6.0    6.0    0.0    0.0      6      1      1       0
# ..     ...  ...    ...    ...    ...    ...    ...    ...    ...     ...
# 155      0  ...    4.0    4.0    0.0    6.0      6      0      2       3
# 156      2  ...    6.0    1.0    1.0    1.0      1      6      0       0
# 157      0  ...    4.0    6.0    0.0    2.0      2      0      4       2
# 158      0  ...    0.0    1.0    0.0    1.0      3      4      0       0
# 159      0  ...    2.0    1.0    0.0    6.0      4      5      5       0
#
#      ccs_11  ccs_12
# 0         3       1
# 1         3       6
# 2         6       3
# 3         0       4
# 4         5       4
# ..      ...     ...
# 155       2       5
# 156       0       6
# 157       1       4
# 158       4       2
# 159       1       1
#
# [150 rows x 54 columns]>

# %% [markdown]
# **AGE**

# %%
#Age distribution to find a serious game suitable for our population
plt.hist(df.age, bins=25) #--> la popolazione si concentra tra i 18 e i 55
plt.title('Age')
plt.show()

# %% [markdown]
# **PHQ questionnaire**

# %%
# List of questionnaire column names
questionnaire_columns_phq = ['phq_1', 'phq_2', 'phq_3', 'phq_4', 'phq_5', 'phq_6', 'phq_7', 'phq_8', 'phq_9']

# Create subplots for the histograms
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(9, 9))
axes = axes.flatten()
x_val = [0, 1, 2, 3]

for i, column_name in enumerate(questionnaire_columns_phq):
    ax = axes[i]

    ax.hist(df[column_name], bins=4, rwidth=0.8)
    ax.set_xlabel('Responses')
    ax.set_ylabel('Frequency')
    ax.set_title(column_name)
    ax.set_xticks(x_val)
    ax.set_xticklabels(x_val)

plt.suptitle('PHQ Questionnaire')
plt.tight_layout()
plt.show()

# %% [markdown]
# **GAD questionnaire**

# %%
# List of questionnaire column names
questionnaire_columns_gad = ['gad_1', 'gad_2', 'gad_3', 'gad_4', 'gad_5', 'gad_6', 'gad_7']

# Create subplots for the histograms
fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(9, 9))
axes = axes.flatten()
x_val = [0, 1, 2, 3]

# Create histograms for each column and plot them in subplots
for i, column_name in enumerate(questionnaire_columns_gad):
    ax = axes[i]
    ax.hist(df[column_name], bins=4, rwidth=0.8)
    ax.set_xlabel('Responses')
    ax.set_ylabel('Frequency')
    ax.set_title(column_name)
    ax.set_xticks(x_val)
    ax.set_xticklabels(x_val)

plt.suptitle('GAD Questionnaire')
plt.tight_layout()
plt.show()

# %% [markdown]
# **EHEALS questionnaire**

# %%
# List of questionnaire column names
questionnaire_columns_eheals = ['eheals_1', 'eheals_2', 'eheals_3', 'eheals_4', 'eheals_5', 'eheals_6', 'eheals_7', 'eheals_8']

# Create subplots for the histograms
fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(9, 9))
axes = axes.flatten()
x_val = [1, 2, 3, 4, 5]

# Create histograms for each column and plot them in subplots
for i, column_name in enumerate(questionnaire_columns_eheals):
    ax = axes[i]
    ax.hist(df[column_name], bins=5, rwidth=0.8)
    ax.set_xlabel('Responses')
    ax.set_ylabel('Frequency')
    ax.set_title(column_name)
    ax.set_xticks(x_val)
    ax.set_xticklabels(x_val)

plt.suptitle('EHEALS Questionnaire')
plt.tight_layout()
plt.show()

# %% [markdown]
# **HEAS questionnaire**

# %%
###heas questionnaire
# List of questionnaire column names
questionnaire_columns_heas = ['heas_1', 'heas_2', 'heas_3', 'heas_4', 'heas_5', 'heas_6', 'heas_7', 'heas_8', 'heas_9', 'heas_10', 'heas_11', 'heas_12', 'heas_13']

# Create subplots for the histograms
fig, axes = plt.subplots(nrows=5, ncols=3, figsize=(9, 9))
axes = axes.flatten()
x_val = [0, 1, 2, 3]

# Create histograms for each column and plot them in subplots
for i, column_name in enumerate(questionnaire_columns_heas):
    ax = axes[i]
    ax.hist(df[column_name], bins=4, rwidth=0.8)
    ax.set_xlabel('Responses')
    ax.set_ylabel('Frequency')
    ax.set_title(column_name)
    ax.set_xticks(x_val)
    ax.set_xticklabels(x_val)

plt.suptitle('HEAS Questionnaire')
plt.tight_layout()
plt.show()

# %% [markdown]
# **CCS questionnaire**

# %%
###ccs questionnaire
# List of questionnaire column names
questionnaire_columns_ccs = ['ccs_1', 'ccs_2', 'ccs_3', 'ccs_4', 'ccs_5', 'ccs_6', 'ccs_7', 'ccs_8', 'ccs_9', 'ccs_10', 'ccs_11', 'ccs_12']

# Create subplots for the histograms
fig, axes = plt.subplots(nrows=4, ncols=3, figsize=(9, 9))
axes = axes.flatten()
x_val = [0, 1, 2, 3, 4, 5, 6]

# Create histograms for each column and plot them in subplots
for i, column_name in enumerate(questionnaire_columns_ccs):
    ax = axes[i]
    ax.hist(df[column_name], bins=7, rwidth=0.8)
    ax.set_xlabel('Responses')
    ax.set_ylabel('Frequency')
    ax.set_title(column_name)
    ax.set_xticks(x_val)
    ax.set_xticklabels(x_val)

plt.suptitle('CCS Questionnaire')
plt.tight_layout()
plt.show()
